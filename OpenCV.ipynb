# %% [markdown]
# <a href="https://colab.research.google.com/github/DinukiFernando/Face-Detection-with-OpenCV/blob/main/OpenCV.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
print(cv2.__version__)
# Out:
# 4.8.0

# %% [markdown]
# Reading the image and printing the dimensions

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
image = '/content/drive/MyDrive/Happy 3.jpg'

# %%
image = cv2.imread('/content/drive/MyDrive/Happy 3.jpg')
x,y = image.shape[:2]
print("Heighe={}, width={}".format(x,y))
# Out:
# Heighe=434, width=612

# %% [markdown]
# Extracting the RGB values of pixels

# %%
(R, G, B) = image[250, 250]
print("R = {}, G ={}, B={}".format(R, G, B))

B = image[250, 250, 0]
print('Just the value of B = {}'.format(B))
# Out:
# R = 23, G =39, B=52
# Just the value of B = 23

# %% [markdown]
# Resizing the image to any dimension

# %%
size = cv2.resize(image, (1920,1080))
cv2.imwrite("newimage3.jpg", image)
# Out:
# True

# %% [markdown]
# Placing a box around any pixel

# %%
rectangle = cv2.rectangle(image,(501,500),(100,50),(255,0,0),2)
cv2.imwrite('newimage3.jpg',image)
# Out:
# True

# %% [markdown]
# Adding  a text to the screen

# %%
text_input = cv2.putText(image, "face",(100,50),cv2.FONT_HERSHEY_SIMPLEX,2,(255,0,0),2)
cv2.imwrite('newimage3.jpg',image)
# Out:
# True

# %% [markdown]
# cv2_imshow example

# %%
import imutils
from google.colab.patches import cv2_imshow
import cv2

image = cv2.imread("newimage3.jpg")
cv2_imshow(image)
# Out:
# <PIL.Image.Image image mode=RGB size=612x434>

# %% [markdown]
# Face detection

# %%
face_cascade = cv2.CascadeClassifier()
